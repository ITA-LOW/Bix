# %%
import pandas as pd
import datetime as dt
import seaborn as sns
import matplotlib.pyplot as plt

# %%
url = 'https://raw.githubusercontent.com/ITA-LOW/teste_Bix/main/Base%20de%20dados/Base%20de%20Dados%20-%20Question%C3%A1rio.xlsx%20-%20Sheet1.csv'
df = pd.read_csv(url)

# %%
df
# Out:
#        Unnamed: 0  Unnamed: 1                        Unnamed: 2  \
# 0             NaN         NaN                               NaN
# 1             NaN         NaN                               NaN
# 2             NaN         NaN                               NaN
# 3             NaN         NaN                                ID
# 4             NaN         NaN  80260d682079b6090c8285b398c50d97
# ...           ...         ...                               ...
# 32752         NaN         NaN  b155e2a8589d40bc9c0381ee48e3204f
# 32753         NaN         NaN  abb71d0110c4be1a1a0c52f929cab4a3
# 32754         NaN         NaN  db9a034f34174edd577b9f64cc982952
# 32755         NaN         NaN  ee00fa5093eb96d8573403b382fb60a8
# 32756         NaN         NaN  56c87d433bb46c7862e35e791b1907fa
#
#                               Unnamed: 3 Unnamed: 4 Unnamed: 5 Unnamed: 6  \
# 0                                    NaN        NaN        NaN        NaN
# 1                                    NaN        NaN        NaN        NaN
# 2                                    NaN        NaN        NaN        NaN
# 3                              ProductID   ClientID   Discount  UnitPrice
# 4      002552c0663708129c0019cc97552d7d3      14001       0,08      249,2
# ...                                  ...        ...        ...        ...
# 32752  002ec297b1b00fb9dde7ee6ac24b67712      28694       0,08      218,4
# 32753  002d4ea7c04739c130bb74d7e7cd16943      28694       0,08        210
# 32754  001795ec6f1b187d37335e1c4704762e3      28694       0,08      148,4
# 32755  002ec297b1b00fb9dde7ee6ac24b67713      28694        0,1      218,4
# 32756  0009406fd7479715e4bef61dd91f24622      28695        0,1      254,8
#
#       Unnamed: 7 Unnamed: 8  Unnamed: 9
# 0            NaN        NaN         NaN
# 1            NaN        NaN         NaN
# 2            NaN        NaN         NaN
# 3       Quantity    StoreID        Date
# 4              1          4  12/10/2018
# ...          ...        ...         ...
# 32752          1          4   12/2/2018
# 32753          1          4   12/5/2018
# 32754          1          4    8/1/2019
# 32755          2          4  11/25/2019
# 32756          1          4    7/4/2018
#
# [32757 rows x 10 columns]

# %%
df.drop([0,1,2])
# Out:
#        Unnamed: 0  Unnamed: 1                        Unnamed: 2  \
# 3             NaN         NaN                                ID
# 4             NaN         NaN  80260d682079b6090c8285b398c50d97
# 5             NaN         NaN  3275736da1234f55d52bdf09d86b93bc
# 6             NaN         NaN  f3513eec8f1434b5b7e04ddf3598df40
# 7             NaN         NaN  7180475b60fe6bbbde424d39704a1177
# ...           ...         ...                               ...
# 32752         NaN         NaN  b155e2a8589d40bc9c0381ee48e3204f
# 32753         NaN         NaN  abb71d0110c4be1a1a0c52f929cab4a3
# 32754         NaN         NaN  db9a034f34174edd577b9f64cc982952
# 32755         NaN         NaN  ee00fa5093eb96d8573403b382fb60a8
# 32756         NaN         NaN  56c87d433bb46c7862e35e791b1907fa
#
#                               Unnamed: 3 Unnamed: 4 Unnamed: 5 Unnamed: 6  \
# 3                              ProductID   ClientID   Discount  UnitPrice
# 4      002552c0663708129c0019cc97552d7d3      14001       0,08      249,2
# 5      001b237c0e9bb435f2e54071129237e93      14001        0,1      162,4
# 6      00066f42aeeb9f3007548bb9d3f33c381      14001        0,1      194,6
# 7      001b72dfd63e9833e8c02742adf472e33      14002        0,1      201,6
# ...                                  ...        ...        ...        ...
# 32752  002ec297b1b00fb9dde7ee6ac24b67712      28694       0,08      218,4
# 32753  002d4ea7c04739c130bb74d7e7cd16943      28694       0,08        210
# 32754  001795ec6f1b187d37335e1c4704762e3      28694       0,08      148,4
# 32755  002ec297b1b00fb9dde7ee6ac24b67713      28694        0,1      218,4
# 32756  0009406fd7479715e4bef61dd91f24622      28695        0,1      254,8
#
#       Unnamed: 7 Unnamed: 8  Unnamed: 9
# 3       Quantity    StoreID        Date
# 4              1          4  12/10/2018
# 5              1          4   4/25/2019
# 6              1          4   7/17/2019
# 7              2          1   4/10/2018
# ...          ...        ...         ...
# 32752          1          4   12/2/2018
# 32753          1          4   12/5/2018
# 32754          1          4    8/1/2019
# 32755          2          4  11/25/2019
# 32756          1          4    7/4/2018
#
# [32754 rows x 10 columns]

# %%
df.iloc[3]
# Out:
# Unnamed: 0          NaN
# Unnamed: 1          NaN
# Unnamed: 2           ID
# Unnamed: 3    ProductID
# Unnamed: 4     ClientID
# Unnamed: 5     Discount
# Unnamed: 6    UnitPrice
# Unnamed: 7     Quantity
# Unnamed: 8      StoreID
# Unnamed: 9         Date
# Name: 3, dtype: object

# %%
df.drop(columns=['Unnamed: 0',	'Unnamed: 1'], inplace=True)

# %%
df.drop([0,1,2], inplace=True)

# %%
df.columns=['ID',	'ProductID',	'ClientID',	'Discount',	'UnitPrice',	'Quantity',	'StoreID',	'Date']

# %%
df.drop([3], inplace=True)
df
# Out:
#                                      ID                          ProductID  \
# 4      80260d682079b6090c8285b398c50d97  002552c0663708129c0019cc97552d7d3
# 5      3275736da1234f55d52bdf09d86b93bc  001b237c0e9bb435f2e54071129237e93
# 6      f3513eec8f1434b5b7e04ddf3598df40  00066f42aeeb9f3007548bb9d3f33c381
# 7      7180475b60fe6bbbde424d39704a1177  001b72dfd63e9833e8c02742adf472e33
# 8      76600853a200fe87e141adae6b35674c  00210e41887c2a8ef9f791ebc780cc363
# ...                                 ...                                ...
# 32752  b155e2a8589d40bc9c0381ee48e3204f  002ec297b1b00fb9dde7ee6ac24b67712
# 32753  abb71d0110c4be1a1a0c52f929cab4a3  002d4ea7c04739c130bb74d7e7cd16943
# 32754  db9a034f34174edd577b9f64cc982952  001795ec6f1b187d37335e1c4704762e3
# 32755  ee00fa5093eb96d8573403b382fb60a8  002ec297b1b00fb9dde7ee6ac24b67713
# 32756  56c87d433bb46c7862e35e791b1907fa  0009406fd7479715e4bef61dd91f24622
#
#       ClientID Discount UnitPrice Quantity StoreID        Date
# 4        14001     0,08     249,2        1       4  12/10/2018
# 5        14001      0,1     162,4        1       4   4/25/2019
# 6        14001      0,1     194,6        1       4   7/17/2019
# 7        14002      0,1     201,6        2       1   4/10/2018
# 8        14002      0,1       406        1       1   1/21/2019
# ...        ...      ...       ...      ...     ...         ...
# 32752    28694     0,08     218,4        1       4   12/2/2018
# 32753    28694     0,08       210        1       4   12/5/2018
# 32754    28694     0,08     148,4        1       4    8/1/2019
# 32755    28694      0,1     218,4        2       4  11/25/2019
# 32756    28695      0,1     254,8        1       4    7/4/2018
#
# [32753 rows x 8 columns]

# %%
df.isnull().sum()
# Out:
# ID           0
# ProductID    0
# ClientID     0
# Discount     0
# UnitPrice    0
# Quantity     0
# StoreID      0
# Date         0
# dtype: int64

# %%
df.isna().sum()
# Out:
# ID           0
# ProductID    0
# ClientID     0
# Discount     0
# UnitPrice    0
# Quantity     0
# StoreID      0
# Date         0
# dtype: int64

# %%
df.dtypes
# Out:
# ID           object
# ProductID    object
# ClientID     object
# Discount     object
# UnitPrice    object
# Quantity     object
# StoreID      object
# Date         object
# dtype: object

# %%
df['Date'] = pd.to_datetime(df.Date,dayfirst = True, infer_datetime_format=True)
# Out:
# C:\Users\ITA\anaconda3\lib\site-packages\pandas\core\tools\datetimes.py:1047: UserWarning: Parsing '12/30/2019' in MM/DD/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# C:\Users\ITA\anaconda3\lib\site-packages\pandas\core\tools\datetimes.py:1047: UserWarning: Parsing '10/27/2018' in MM/DD/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# C:\Users\ITA\anaconda3\lib\site-packages\pandas\core\tools\datetimes.py:1047: UserWarning: Parsing '10/22/2018' in MM/DD/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# C:\Users\ITA\anaconda3\lib\site-packages\pandas\core\tools\datetimes.py:1047: UserWarning: Parsing '11/27/2018' in MM/DD/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# C:\Users\ITA\anaconda3\lib\site-packages\pandas\core\tools\datetimes.py:1047: UserWarning: Parsing '12/31/2018' in MM/DD/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# C:\Users\ITA\anaconda3\lib\site-packages\pandas\core\tools\datetimes.py:1047: UserWarning: Parsing '11/13/2019' in MM/DD/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# C:\Users\ITA\anaconda3\lib\site-packages\pandas\core\tools\datetimes.py:1047: UserWarning: Parsing '11/23/2019' in MM/DD/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# C:\Users\ITA\anaconda3\lib\site-packages\pandas\core\tools\datetimes.py:1047: UserWarning: Parsing '10/25/2019' in MM/DD/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# C:\Users\ITA\anaconda3\lib\site-packages\pandas\core\tools\datetimes.py:1047: UserWarning: Parsing '10/18/2019' in MM/DD/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# C:\Users\ITA\anaconda3\lib\site-packages\pandas\core\tools\datetimes.py:1047: UserWarning: Parsing '11/15/2018' in MM/DD/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# C:\Users\ITA\anaconda3\lib\site-packages\pandas\core\tools\datetimes.py:1047: UserWarning: Parsing '12/31/2019' in MM/DD/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# C:\Users\ITA\anaconda3\lib\site-packages\pandas\core\tools\datetimes.py:1047: UserWarning: Parsing '12/13/2018' in MM/DD/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# C:\Users\ITA\anaconda3\lib\site-packages\pandas\core\tools\datetimes.py:1047: UserWarning: Parsing '11/28/2019' in MM/DD/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# C:\Users\ITA\anaconda3\lib\site-packages\pandas\core\tools\datetimes.py:1047: UserWarning: Parsing '12/26/2019' in MM/DD/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# C:\Users\ITA\anaconda3\lib\site-packages\pandas\core\tools\datetimes.py:1047: UserWarning: Parsing '11/21/2019' in MM/DD/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# C:\Users\ITA\anaconda3\lib\site-packages\pandas\core\tools\datetimes.py:1047: UserWarning: Parsing '12/16/2019' in MM/DD/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# C:\Users\ITA\anaconda3\lib\site-packages\pandas\core\tools\datetimes.py:1047: UserWarning: Parsing '12/28/2018' in MM/DD/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# C:\Users\ITA\anaconda3\lib\site-packages\pandas\core\tools\datetimes.py:1047: UserWarning: Parsing '10/23/2018' in MM/DD/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# C:\Users\ITA\anaconda3\lib\site-packages\pandas\core\tools\datetimes.py:1047: UserWarning: Parsing '11/18/2018' in MM/DD/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# C:\Users\ITA\anaconda3\lib\site-packages\pandas\core\tools\datetimes.py:1047: UserWarning: Parsing '10/26/2019' in MM/DD/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# C:\Users\ITA\anaconda3\lib\site-packages\pandas\core\tools\datetimes.py:1047: UserWarning: Parsing '12/20/2019' in MM/DD/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# C:\Users\ITA\anaconda3\lib\site-packages\pandas\core\tools\datetimes.py:1047: UserWarning: Parsing '11/22/2018' in MM/DD/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# C:\Users\ITA\anaconda3\lib\site-packages\pandas\core\tools\datetimes.py:1047: UserWarning: Parsing '12/23/2018' in MM/DD/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# C:\Users\ITA\anaconda3\lib\site-packages\pandas\core\tools\datetimes.py:1047: UserWarning: Parsing '12/29/2018' in MM/DD/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# C:\Users\ITA\anaconda3\lib\site-packages\pandas\core\tools\datetimes.py:1047: UserWarning: Parsing '10/21/2019' in MM/DD/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# C:\Users\ITA\anaconda3\lib\site-packages\pandas\core\tools\datetimes.py:1047: UserWarning: Parsing '10/29/2018' in MM/DD/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# C:\Users\ITA\anaconda3\lib\site-packages\pandas\core\tools\datetimes.py:1047: UserWarning: Parsing '12/21/2019' in MM/DD/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# C:\Users\ITA\anaconda3\lib\site-packages\pandas\core\tools\datetimes.py:1047: UserWarning: Parsing '12/13/2019' in MM/DD/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# C:\Users\ITA\anaconda3\lib\site-packages\pandas\core\tools\datetimes.py:1047: UserWarning: Parsing '10/15/2019' in MM/DD/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# C:\Users\ITA\anaconda3\lib\site-packages\pandas\core\tools\datetimes.py:1047: UserWarning: Parsing '12/24/2018' in MM/DD/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# C:\Users\ITA\anaconda3\lib\site-packages\pandas\core\tools\datetimes.py:1047: UserWarning: Parsing '12/17/2018' in MM/DD/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# C:\Users\ITA\anaconda3\lib\site-packages\pandas\core\tools\datetimes.py:1047: UserWarning: Parsing '12/27/2018' in MM/DD/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# C:\Users\ITA\anaconda3\lib\site-packages\pandas\core\tools\datetimes.py:1047: UserWarning: Parsing '10/28/2018' in MM/DD/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# C:\Users\ITA\anaconda3\lib\site-packages\pandas\core\tools\datetimes.py:1047: UserWarning: Parsing '12/18/2018' in MM/DD/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# C:\Users\ITA\anaconda3\lib\site-packages\pandas\core\tools\datetimes.py:1047: UserWarning: Parsing '10/25/2018' in MM/DD/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# C:\Users\ITA\anaconda3\lib\site-packages\pandas\core\tools\datetimes.py:1047: UserWarning: Parsing '12/18/2019' in MM/DD/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# C:\Users\ITA\anaconda3\lib\site-packages\pandas\core\tools\datetimes.py:1047: UserWarning: Parsing '10/20/2018' in MM/DD/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# C:\Users\ITA\anaconda3\lib\site-packages\pandas\core\tools\datetimes.py:1047: UserWarning: Parsing '12/14/2018' in MM/DD/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# C:\Users\ITA\anaconda3\lib\site-packages\pandas\core\tools\datetimes.py:1047: UserWarning: Parsing '11/30/2019' in MM/DD/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# C:\Users\ITA\anaconda3\lib\site-packages\pandas\core\tools\datetimes.py:1047: UserWarning: Parsing '12/30/2018' in MM/DD/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# C:\Users\ITA\anaconda3\lib\site-packages\pandas\core\tools\datetimes.py:1047: UserWarning: Parsing '11/24/2018' in MM/DD/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# C:\Users\ITA\anaconda3\lib\site-packages\pandas\core\tools\datetimes.py:1047: UserWarning: Parsing '11/30/2018' in MM/DD/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# C:\Users\ITA\anaconda3\lib\site-packages\pandas\core\tools\datetimes.py:1047: UserWarning: Parsing '11/14/2019' in MM/DD/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# C:\Users\ITA\anaconda3\lib\site-packages\pandas\core\tools\datetimes.py:1047: UserWarning: Parsing '10/21/2018' in MM/DD/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# C:\Users\ITA\anaconda3\lib\site-packages\pandas\core\tools\datetimes.py:1047: UserWarning: Parsing '12/19/2018' in MM/DD/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# C:\Users\ITA\anaconda3\lib\site-packages\pandas\core\tools\datetimes.py:1047: UserWarning: Parsing '11/29/2018' in MM/DD/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# C:\Users\ITA\anaconda3\lib\site-packages\pandas\core\tools\datetimes.py:1047: UserWarning: Parsing '10/18/2018' in MM/DD/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# C:\Users\ITA\anaconda3\lib\site-packages\pandas\core\tools\datetimes.py:1047: UserWarning: Parsing '12/14/2019' in MM/DD/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# C:\Users\ITA\anaconda3\lib\site-packages\pandas\core\tools\datetimes.py:1047: UserWarning: Parsing '11/25/2019' in MM/DD/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# C:\Users\ITA\anaconda3\lib\site-packages\pandas\core\tools\datetimes.py:1047: UserWarning: Parsing '11/14/2018' in MM/DD/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# C:\Users\ITA\anaconda3\lib\site-packages\pandas\core\tools\datetimes.py:1047: UserWarning: Parsing '12/27/2019' in MM/DD/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# C:\Users\ITA\anaconda3\lib\site-packages\pandas\core\tools\datetimes.py:1047: UserWarning: Parsing '11/24/2019' in MM/DD/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# C:\Users\ITA\anaconda3\lib\site-packages\pandas\core\tools\datetimes.py:1047: UserWarning: Parsing '10/13/2018' in MM/DD/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# C:\Users\ITA\anaconda3\lib\site-packages\pandas\core\tools\datetimes.py:1047: UserWarning: Parsing '11/29/2019' in MM/DD/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# C:\Users\ITA\anaconda3\lib\site-packages\pandas\core\tools\datetimes.py:1047: UserWarning: Parsing '11/26/2018' in MM/DD/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# C:\Users\ITA\anaconda3\lib\site-packages\pandas\core\tools\datetimes.py:1047: UserWarning: Parsing '11/20/2019' in MM/DD/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# C:\Users\ITA\anaconda3\lib\site-packages\pandas\core\tools\datetimes.py:1047: UserWarning: Parsing '11/17/2019' in MM/DD/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# C:\Users\ITA\anaconda3\lib\site-packages\pandas\core\tools\datetimes.py:1047: UserWarning: Parsing '12/17/2019' in MM/DD/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# C:\Users\ITA\anaconda3\lib\site-packages\pandas\core\tools\datetimes.py:1047: UserWarning: Parsing '11/16/2018' in MM/DD/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# C:\Users\ITA\anaconda3\lib\site-packages\pandas\core\tools\datetimes.py:1047: UserWarning: Parsing '11/28/2018' in MM/DD/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# C:\Users\ITA\anaconda3\lib\site-packages\pandas\core\tools\datetimes.py:1047: UserWarning: Parsing '10/31/2018' in MM/DD/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# C:\Users\ITA\anaconda3\lib\site-packages\pandas\core\tools\datetimes.py:1047: UserWarning: Parsing '10/17/2018' in MM/DD/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# C:\Users\ITA\anaconda3\lib\site-packages\pandas\core\tools\datetimes.py:1047: UserWarning: Parsing '11/21/2018' in MM/DD/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# C:\Users\ITA\anaconda3\lib\site-packages\pandas\core\tools\datetimes.py:1047: UserWarning: Parsing '12/25/2018' in MM/DD/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# C:\Users\ITA\anaconda3\lib\site-packages\pandas\core\tools\datetimes.py:1047: UserWarning: Parsing '10/27/2019' in MM/DD/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# C:\Users\ITA\anaconda3\lib\site-packages\pandas\core\tools\datetimes.py:1047: UserWarning: Parsing '12/16/2018' in MM/DD/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# C:\Users\ITA\anaconda3\lib\site-packages\pandas\core\tools\datetimes.py:1047: UserWarning: Parsing '11/16/2019' in MM/DD/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# C:\Users\ITA\anaconda3\lib\site-packages\pandas\core\tools\datetimes.py:1047: UserWarning: Parsing '12/24/2019' in MM/DD/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# C:\Users\ITA\anaconda3\lib\site-packages\pandas\core\tools\datetimes.py:1047: UserWarning: Parsing '11/13/2018' in MM/DD/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# C:\Users\ITA\anaconda3\lib\site-packages\pandas\core\tools\datetimes.py:1047: UserWarning: Parsing '10/16/2019' in MM/DD/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# C:\Users\ITA\anaconda3\lib\site-packages\pandas\core\tools\datetimes.py:1047: UserWarning: Parsing '10/24/2019' in MM/DD/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# C:\Users\ITA\anaconda3\lib\site-packages\pandas\core\tools\datetimes.py:1047: UserWarning: Parsing '10/14/2018' in MM/DD/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# C:\Users\ITA\anaconda3\lib\site-packages\pandas\core\tools\datetimes.py:1047: UserWarning: Parsing '12/26/2018' in MM/DD/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# C:\Users\ITA\anaconda3\lib\site-packages\pandas\core\tools\datetimes.py:1047: UserWarning: Parsing '11/25/2018' in MM/DD/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# C:\Users\ITA\anaconda3\lib\site-packages\pandas\core\tools\datetimes.py:1047: UserWarning: Parsing '10/30/2019' in MM/DD/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# C:\Users\ITA\anaconda3\lib\site-packages\pandas\core\tools\datetimes.py:1047: UserWarning: Parsing '12/21/2018' in MM/DD/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# C:\Users\ITA\anaconda3\lib\site-packages\pandas\core\tools\datetimes.py:1047: UserWarning: Parsing '10/14/2019' in MM/DD/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# C:\Users\ITA\anaconda3\lib\site-packages\pandas\core\tools\datetimes.py:1047: UserWarning: Parsing '12/28/2019' in MM/DD/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# C:\Users\ITA\anaconda3\lib\site-packages\pandas\core\tools\datetimes.py:1047: UserWarning: Parsing '12/15/2018' in MM/DD/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# C:\Users\ITA\anaconda3\lib\site-packages\pandas\core\tools\datetimes.py:1047: UserWarning: Parsing '12/22/2018' in MM/DD/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# C:\Users\ITA\anaconda3\lib\site-packages\pandas\core\tools\datetimes.py:1047: UserWarning: Parsing '10/31/2019' in MM/DD/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# C:\Users\ITA\anaconda3\lib\site-packages\pandas\core\tools\datetimes.py:1047: UserWarning: Parsing '12/19/2019' in MM/DD/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# C:\Users\ITA\anaconda3\lib\site-packages\pandas\core\tools\datetimes.py:1047: UserWarning: Parsing '12/29/2019' in MM/DD/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# C:\Users\ITA\anaconda3\lib\site-packages\pandas\core\tools\datetimes.py:1047: UserWarning: Parsing '10/13/2019' in MM/DD/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# C:\Users\ITA\anaconda3\lib\site-packages\pandas\core\tools\datetimes.py:1047: UserWarning: Parsing '11/26/2019' in MM/DD/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# C:\Users\ITA\anaconda3\lib\site-packages\pandas\core\tools\datetimes.py:1047: UserWarning: Parsing '12/22/2019' in MM/DD/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# C:\Users\ITA\anaconda3\lib\site-packages\pandas\core\tools\datetimes.py:1047: UserWarning: Parsing '12/25/2019' in MM/DD/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# C:\Users\ITA\anaconda3\lib\site-packages\pandas\core\tools\datetimes.py:1047: UserWarning: Parsing '10/29/2019' in MM/DD/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# C:\Users\ITA\anaconda3\lib\site-packages\pandas\core\tools\datetimes.py:1047: UserWarning: Parsing '11/19/2018' in MM/DD/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# C:\Users\ITA\anaconda3\lib\site-packages\pandas\core\tools\datetimes.py:1047: UserWarning: Parsing '10/22/2019' in MM/DD/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# C:\Users\ITA\anaconda3\lib\site-packages\pandas\core\tools\datetimes.py:1047: UserWarning: Parsing '11/27/2019' in MM/DD/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# C:\Users\ITA\anaconda3\lib\site-packages\pandas\core\tools\datetimes.py:1047: UserWarning: Parsing '10/19/2018' in MM/DD/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# C:\Users\ITA\anaconda3\lib\site-packages\pandas\core\tools\datetimes.py:1047: UserWarning: Parsing '11/20/2018' in MM/DD/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# C:\Users\ITA\anaconda3\lib\site-packages\pandas\core\tools\datetimes.py:1047: UserWarning: Parsing '12/15/2019' in MM/DD/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# C:\Users\ITA\anaconda3\lib\site-packages\pandas\core\tools\datetimes.py:1047: UserWarning: Parsing '11/23/2018' in MM/DD/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# C:\Users\ITA\anaconda3\lib\site-packages\pandas\core\tools\datetimes.py:1047: UserWarning: Parsing '11/17/2018' in MM/DD/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# C:\Users\ITA\anaconda3\lib\site-packages\pandas\core\tools\datetimes.py:1047: UserWarning: Parsing '11/22/2019' in MM/DD/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# C:\Users\ITA\anaconda3\lib\site-packages\pandas\core\tools\datetimes.py:1047: UserWarning: Parsing '10/28/2019' in MM/DD/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# C:\Users\ITA\anaconda3\lib\site-packages\pandas\core\tools\datetimes.py:1047: UserWarning: Parsing '10/26/2018' in MM/DD/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# C:\Users\ITA\anaconda3\lib\site-packages\pandas\core\tools\datetimes.py:1047: UserWarning: Parsing '10/30/2018' in MM/DD/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# C:\Users\ITA\anaconda3\lib\site-packages\pandas\core\tools\datetimes.py:1047: UserWarning: Parsing '10/15/2018' in MM/DD/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# C:\Users\ITA\anaconda3\lib\site-packages\pandas\core\tools\datetimes.py:1047: UserWarning: Parsing '11/19/2019' in MM/DD/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# C:\Users\ITA\anaconda3\lib\site-packages\pandas\core\tools\datetimes.py:1047: UserWarning: Parsing '12/23/2019' in MM/DD/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# C:\Users\ITA\anaconda3\lib\site-packages\pandas\core\tools\datetimes.py:1047: UserWarning: Parsing '10/23/2019' in MM/DD/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# C:\Users\ITA\anaconda3\lib\site-packages\pandas\core\tools\datetimes.py:1047: UserWarning: Parsing '12/20/2018' in MM/DD/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# C:\Users\ITA\anaconda3\lib\site-packages\pandas\core\tools\datetimes.py:1047: UserWarning: Parsing '10/16/2018' in MM/DD/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# C:\Users\ITA\anaconda3\lib\site-packages\pandas\core\tools\datetimes.py:1047: UserWarning: Parsing '10/19/2019' in MM/DD/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# C:\Users\ITA\anaconda3\lib\site-packages\pandas\core\tools\datetimes.py:1047: UserWarning: Parsing '10/20/2019' in MM/DD/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# C:\Users\ITA\anaconda3\lib\site-packages\pandas\core\tools\datetimes.py:1047: UserWarning: Parsing '10/24/2018' in MM/DD/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# C:\Users\ITA\anaconda3\lib\site-packages\pandas\core\tools\datetimes.py:1047: UserWarning: Parsing '10/17/2019' in MM/DD/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# C:\Users\ITA\anaconda3\lib\site-packages\pandas\core\tools\datetimes.py:1047: UserWarning: Parsing '11/18/2019' in MM/DD/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# C:\Users\ITA\anaconda3\lib\site-packages\pandas\core\tools\datetimes.py:1047: UserWarning: Parsing '11/15/2019' in MM/DD/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)

# %%
df.dtypes
# Out:
# ID                   object
# ProductID            object
# ClientID             object
# Discount             object
# UnitPrice            object
# Quantity             object
# StoreID              object
# Date         datetime64[ns]
# dtype: object

# %%
df.groupby(['StoreID'], dropna=False).size().sort_values(ascending=False)
# Out:
# StoreID
# 1     8230
# 2     6838
# 3     6167
# 4     5172
# 7     3588
# 9     1845
# 22     913
# dtype: int64

# %%
df['Discount'] = df['Discount'].str.replace(',','.').astype(float)

# %%
df['UnitPrice'] = df['UnitPrice'].str.replace(',','.').astype(float)

# %%
df.dtypes
# Out:
# ID                   object
# ProductID            object
# ClientID             object
# Discount            float64
# UnitPrice           float64
# Quantity             object
# StoreID              object
# Date         datetime64[ns]
# dtype: object

# %%
df.describe().T
# Out:
#              count        mean         std     min     25%    50%    75%  \
# Discount   32753.0    0.093012    0.009536    0.08    0.08    0.1    0.1
# UnitPrice  32753.0  221.644967  112.535304  114.80  161.00  204.4  233.8
#
#              max
# Discount     0.1
# UnitPrice  686.0

# %%
df
# Out:
#                                      ID                          ProductID  \
# 4      80260d682079b6090c8285b398c50d97  002552c0663708129c0019cc97552d7d3
# 5      3275736da1234f55d52bdf09d86b93bc  001b237c0e9bb435f2e54071129237e93
# 6      f3513eec8f1434b5b7e04ddf3598df40  00066f42aeeb9f3007548bb9d3f33c381
# 7      7180475b60fe6bbbde424d39704a1177  001b72dfd63e9833e8c02742adf472e33
# 8      76600853a200fe87e141adae6b35674c  00210e41887c2a8ef9f791ebc780cc363
# ...                                 ...                                ...
# 32752  b155e2a8589d40bc9c0381ee48e3204f  002ec297b1b00fb9dde7ee6ac24b67712
# 32753  abb71d0110c4be1a1a0c52f929cab4a3  002d4ea7c04739c130bb74d7e7cd16943
# 32754  db9a034f34174edd577b9f64cc982952  001795ec6f1b187d37335e1c4704762e3
# 32755  ee00fa5093eb96d8573403b382fb60a8  002ec297b1b00fb9dde7ee6ac24b67713
# 32756  56c87d433bb46c7862e35e791b1907fa  0009406fd7479715e4bef61dd91f24622
#
#       ClientID  Discount  UnitPrice Quantity StoreID       Date
# 4        14001      0.08      249.2        1       4 2018-10-12
# 5        14001      0.10      162.4        1       4 2019-04-25
# 6        14001      0.10      194.6        1       4 2019-07-17
# 7        14002      0.10      201.6        2       1 2018-10-04
# 8        14002      0.10      406.0        1       1 2019-01-21
# ...        ...       ...        ...      ...     ...        ...
# 32752    28694      0.08      218.4        1       4 2018-02-12
# 32753    28694      0.08      210.0        1       4 2018-05-12
# 32754    28694      0.08      148.4        1       4 2019-01-08
# 32755    28694      0.10      218.4        2       4 2019-11-25
# 32756    28695      0.10      254.8        1       4 2018-04-07
#
# [32753 rows x 8 columns]

# %%
df['ano'] = df['Date'].dt.year

# %%
df
# Out:
#                                      ID                          ProductID  \
# 4      80260d682079b6090c8285b398c50d97  002552c0663708129c0019cc97552d7d3
# 5      3275736da1234f55d52bdf09d86b93bc  001b237c0e9bb435f2e54071129237e93
# 6      f3513eec8f1434b5b7e04ddf3598df40  00066f42aeeb9f3007548bb9d3f33c381
# 7      7180475b60fe6bbbde424d39704a1177  001b72dfd63e9833e8c02742adf472e33
# 8      76600853a200fe87e141adae6b35674c  00210e41887c2a8ef9f791ebc780cc363
# ...                                 ...                                ...
# 32752  b155e2a8589d40bc9c0381ee48e3204f  002ec297b1b00fb9dde7ee6ac24b67712
# 32753  abb71d0110c4be1a1a0c52f929cab4a3  002d4ea7c04739c130bb74d7e7cd16943
# 32754  db9a034f34174edd577b9f64cc982952  001795ec6f1b187d37335e1c4704762e3
# 32755  ee00fa5093eb96d8573403b382fb60a8  002ec297b1b00fb9dde7ee6ac24b67713
# 32756  56c87d433bb46c7862e35e791b1907fa  0009406fd7479715e4bef61dd91f24622
#
#       ClientID  Discount  UnitPrice Quantity StoreID       Date   ano
# 4        14001      0.08      249.2        1       4 2018-10-12  2018
# 5        14001      0.10      162.4        1       4 2019-04-25  2019
# 6        14001      0.10      194.6        1       4 2019-07-17  2019
# 7        14002      0.10      201.6        2       1 2018-10-04  2018
# 8        14002      0.10      406.0        1       1 2019-01-21  2019
# ...        ...       ...        ...      ...     ...        ...   ...
# 32752    28694      0.08      218.4        1       4 2018-02-12  2018
# 32753    28694      0.08      210.0        1       4 2018-05-12  2018
# 32754    28694      0.08      148.4        1       4 2019-01-08  2019
# 32755    28694      0.10      218.4        2       4 2019-11-25  2019
# 32756    28695      0.10      254.8        1       4 2018-04-07  2018
#
# [32753 rows x 9 columns]

# %%
df.groupby(['ClientID'], dropna=False).size().sort_values(ascending=False)
# Out:
# ClientID
# 19089    9
# 22056    9
# 17631    9
# 26177    9
# 16316    8
#         ..
# 23021    1
# 23019    1
# 16619    1
# 23016    1
# 28695    1
# Length: 13650, dtype: int64

# %%
#Cliente que mais vezes foi comprar
df.loc[df.ClientID == '19089']
# Out:
#                                      ID                          ProductID  \
# 11415  b779a5a05a7f2a1955da9631df2a275d  001b237c0e9bb435f2e54071129237e93
# 11416  1a44130317893c48ad015ed3ce2017e0  001b237c0e9bb435f2e54071129237e92
# 11417  47df8ca5e5217025971963e512193641  0011c512eb256aa0dbbb544d8dffcf6e3
# 11418  445a17ac1fde5a5ac27faedc9b38318d  00210e41887c2a8ef9f791ebc780cc363
# 11419  b778fd298c71b362595bb3c3cd79c00c  002552c0663708129c0019cc97552d7d3
# 11420  e2f77cbc6c09acfd09a1b89f50c095ff  001795ec6f1b187d37335e1c4704762e3
# 11421  51879b7474407f56048b6c36cc3e263c  002959d7a0b0990fe2d69988affcbc803
# 11422  8e6f3cb506222036edac14e7db634ae2  000d9be29b5207b54e86aa1b1ac548721
# 11423  67a02a73466642c42627bf50de7bea92  0011c512eb256aa0dbbb544d8dffcf6e2
#
#       ClientID  Discount  UnitPrice Quantity StoreID       Date   ano
# 11415    19089      0.10      162.4        1       7 2018-07-04  2018
# 11416    19089      0.10      162.4        1       7 2018-09-05  2018
# 11417    19089      0.10      204.4        1       7 2018-05-23  2018
# 11418    19089      0.08      406.0        1       7 2018-07-06  2018
# 11419    19089      0.10      249.2        1       7 2018-07-14  2018
# 11420    19089      0.10      148.4        1       7 2018-05-11  2018
# 11421    19089      0.10      261.8        1       7 2018-11-26  2018
# 11422    19089      0.08      233.8        1       7 2018-12-23  2018
# 11423    19089      0.10      204.4        1       7 2019-03-31  2019

# %%
df.loc[df.ClientID == '19089'].describe().T
# Out:
#            count         mean        std      min     25%     50%     75%  \
# Discount     9.0     0.095556   0.008819     0.08     0.1     0.1     0.1
# UnitPrice    9.0   225.866667  78.521780   148.40   162.4   204.4   249.2
# ano          9.0  2018.111111   0.333333  2018.00  2018.0  2018.0  2018.0
#
#               max
# Discount      0.1
# UnitPrice   406.0
# ano        2019.0

# %%
sns.set(style='whitegrid', palette="deep", font_scale=1.1, rc={"figure.figsize": [8, 5]})
sns.distplot(
    df['ClientID'], norm_hist=False, kde=False, bins=20, hist_kws={"alpha": 1}
).set(xlabel='ID', ylabel='Contagem', title='Distribuição de frequências');
# Out:
# C:\Users\ITA\anaconda3\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %% [markdown]
# ##banco de dados 2

# %%
url2 = 'https://raw.githubusercontent.com/ITA-LOW/teste_Bix/main/Base%20de%20dados/Base%20de%20Dados%20-%20Question%C3%A1rio.xlsx%20-%20Sheet2.csv'
df2 = pd.read_csv(url2)

# %%
df2
# Out:
#                                    ID             Name Size
# 0   00066f42aeeb9f3007548bb9d3f33c381  Capitão América    P
# 1   00066f42aeeb9f3007548bb9d3f33c382  Capitão América    M
# 2   00066f42aeeb9f3007548bb9d3f33c383  Capitão América    G
# 3   00088930e925c41fd95ebfe695fd26551             Thor    P
# 4   00088930e925c41fd95ebfe695fd26552             Thor    M
# ..                                ...              ...  ...
# 68  0030e635639c898b323826589761cf233       Rick Morty    G
# 69  003128f981470c3e5a2e7445e4a771cd1   Homer Simpsons    P
# 70  003128f981470c3e5a2e7445e4a771cd2   Homer Simpsons    M
# 71  003128f981470c3e5a2e7445e4a771cd3   Homer Simpsons    G
# 72  003128f981470c3e5a2e7445e4a771cd4   Homer Simpsons   GG
#
# [73 rows x 3 columns]

# %%
pd.unique(df2.Name)
# Out:
# array(['Capitão América', 'Thor', 'Deadpool', 'Pantera Negra', 'Batman',
#        'Flash', 'Coringa', 'Mulher-Maravilha', 'Thanos', 'Wolverine',
#        'Capitã Marvel', 'Naruto', 'Pokemon Go Squirtle', 'Super Mario',
#        'BIXDream', 'Tempestade', 'Ciclope', 'Dragon Ball Z',
#        'Darth Vader', 'Iron Man', 'Bazinga', 'League Legends',
#        'Rick Morty', 'Homer Simpsons'], dtype=object)

# %% [markdown]
# ###banco de dados 3

# %%
url3 = 'https://raw.githubusercontent.com/ITA-LOW/teste_Bix/main/Base%20de%20dados/Base%20de%20Dados%20-%20Question%C3%A1rio.xlsx%20-%20Sheet3.csv'
df3 = pd.read_csv(url3)

# %%
df3
# Out:
#           ID            City State DateOfBirth     Sex
# 0      14001        Curitiba    PR   6/28/1985   Homem
# 1      14002   Florianópolis    SC   1/10/1987   Homem
# 2      14003  Rio de Janeiro    RJ   11/5/1979   Homem
# 3      14004  Rio de Janeiro    RJ  11/25/1983  Mulher
# 4      14005   Florianópolis    SC    4/7/1969   Homem
# ...      ...             ...   ...         ...     ...
# 13645  28689  Belo Horizonte    MG   1/15/1999   Homem
# 13646  28691  Belo Horizonte    BH    2/7/1956   Homem
# 13647  28692    Porto Alegre    RS  10/19/1985   Homem
# 13648  28694        Curitiba    PR  10/22/1982   Homem
# 13649  28695        Curitiba    PR  10/24/1961   Homem
#
# [13650 rows x 5 columns]

# %%
df3['DateOfBirth'] = pd.to_datetime(df3.DateOfBirth,dayfirst = True, infer_datetime_format=True)

# %%
df3.dtypes
# Out:
# ID                      int64
# City                   object
# State                  object
# DateOfBirth    datetime64[ns]
# Sex                    object
# dtype: object

# %%
df3.groupby(['Sex'], dropna=False).size().sort_values(ascending=False)
# Out:
# Sex
# Homem     11972
# Mulher     1678
# dtype: int64

# %%
filtro = df3.groupby(['City'], dropna=False).size().sort_values(ascending=False)

# %%
filtro = pd.DataFrame(filtro)

# %%
filtro
# Out:
#                    0
# City
# Florianópolis   3449
# Rio de Janeiro  2810
# Porto Alegre    2536
# Curitiba        2123
# São Paulo       1393
# ...              ...
# Itapeva            1
# Itapetininga       1
# Itajobi            1
# Ibirama            1
# Vitoria            1
#
# [123 rows x 1 columns]

# %%
filtro.reset_index(inplace=True)

# %%
filtro.columns=['cidade','clientes']

# %%
soma = filtro.iloc[0:6]

# %%
plt.bar(soma.cidade,soma.clientes)
# Out:
# <BarContainer object of 6 artists>
